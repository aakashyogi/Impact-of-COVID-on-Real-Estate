# %%
from bs4 import BeautifulSoup as soup
from requests import get
import pandas as pd
import requests
import re

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df11 = pd.DataFrame()

# %%
#Manikonda
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,13):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page == 2)):
        print(page)
        #url ='https://www.makaan.com/listings?beds=1,2,3,3plus&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=manikonda&suburbName=Hyderabad%20West&cityId=12&localityId=51943&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=manikonda&suburbName=Hyderabad%20West&cityId=12&localityId=51943&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=manikonda&suburbName=Hyderabad%20West&cityId=12&localityId=51943&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]
# Out:
# 1
# 2

# %%
df.to_csv('newmanikonda30June.csv',index= False)

# %%
#Miyapur
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,29):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        url ='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=miyapur&suburbName=Hyderabad%20West&cityId=12&localityId=50393&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        #url='https://www.makaan.com/listings?beds=1,2,3,3plus&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=miyapur&suburbName=Hyderabad%20West&cityId=12&localityId=50393&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=miyapur&suburbName=Hyderabad%20West&cityId=12&localityId=50393&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshmiyapurmakkan.csv',index = False)

# %%
#banjara hills
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,5):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=banjara%20hills&suburbName=Hyderabad%20Central&cityId=12&localityId=51628&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=banjara%20hills&suburbName=Hyderabad%20Central&cityId=12&localityId=51628&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=banjara%20hills&suburbName=Hyderabad%20Central&cityId=12&localityId=51628&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshBanjarahillsmakkan.csv',index= False)

# %%
#jublee hills
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,4):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=jubilee%20hills&suburbName=Hyderabad%20Central&cityId=12&localityId=51238&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=jubilee%20hills&suburbName=Hyderabad%20Central&cityId=12&localityId=51238&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY&'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=jubilee%20hills&suburbName=Hyderabad%20Central&cityId=12&localityId=51238&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshJublihillsmakkan.csv',index= False)

# %%
#kondapur
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,20):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=kondapur&suburbName=Hyderabad%20West&cityId=12&localityId=51242&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=kondapur&suburbName=Hyderabad%20West&cityId=12&localityId=51242&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=kondapur&suburbName=Hyderabad%20West&cityId=12&localityId=51242&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshkondapurmakkan.csv',index= False)

# %%
#kothaguda
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,3):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        url ='https://www.makaan.com/listings?sortBy=relevance&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=kothaguda&suburbName=Other&cityId=12&localityId=57579&suburbId=10092&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        #url='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=kothaguda&suburbName=Other&cityId=12&localityId=57579&suburbId=10092&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        url = 'https://www.makaan.com/listings?sortBy=relevance&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=kothaguda&suburbName=Other&cityId=12&localityId=57579&suburbId=10092&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshkothagudamakkan.csv',index= False)

# %%
#Serilingampally
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,4):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=serilingampally&suburbName=Hyderabad%20West&cityId=12&localityId=51989&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url ='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=serilingampally&suburbName=Hyderabad%20West&cityId=12&localityId=51989&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=serilingampally&suburbName=Hyderabad%20West&cityId=12&localityId=51989&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshserilingampallymakkan.csv',index= False)

# %%
#madhapur
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,5):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=madhapur&suburbName=Hyderabad%20West&cityId=12&localityId=51748&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=madhapur&suburbName=Hyderabad%20West&cityId=12&localityId=51748&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=madhapur&suburbName=Hyderabad%20West&cityId=12&localityId=51748&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshmadhapurmakkan.csv',index= False)

# %%
#Gachibowli
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,27):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=gachibowli&suburbName=Hyderabad%20West&cityId=12&localityId=50375&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=gachibowli&suburbName=Hyderabad%20West&cityId=12&localityId=50375&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=gachibowli&suburbName=Hyderabad%20West&cityId=12&localityId=50375&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshGachibowlimakkan.csv',index= False)

# %%
#Hitechcity
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,12):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=hitech%20city&suburbName=Hyderabad%20West&cityId=12&localityId=52077&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=hitech%20city&suburbName=Hyderabad%20West&cityId=12&localityId=52077&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=hitech%20city&suburbName=Hyderabad%20West&cityId=12&localityId=52077&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshhitechmakkan.csv',index= False)

# %%
#somajiguda
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,3):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=somajiguda&suburbName=Hyderabad%20Central&cityId=12&localityId=51971&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=somajiguda&suburbName=Hyderabad%20Central&cityId=12&localityId=51971&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=somajiguda&suburbName=Hyderabad%20Central&cityId=12&localityId=51971&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshsomajigudamakkan.csv',index= False)

# %%
#towlichowki
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,9):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1)):
        url ='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=toli%20chowki&suburbName=Hyderabad%20West&cityId=12&localityId=59819&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        #url='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LISTINGS_PROPERTY_URLS&cityName=Hyderabad&localityName=toli%20chowki&suburbName=Hyderabad%20West&cityId=12&localityId=59819&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=toli%20chowki&suburbName=Hyderabad%20West&cityId=12&localityId=59819&suburbId=10082&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshtolichowkimakkan.csv',index= False)

# %%
#ameerpet
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(1,3):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | ((page == 2))):
        #url ='https://www.makaan.com/listings?beds=1rk,1,2,3,3plus&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=ameerpet&suburbName=Hyderabad%20Central&cityId=12&localityId=51957&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        url = 'https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=ameerpet&suburbName=Hyderabad%20Central&cityId=12&localityId=51957&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY'
        
    else:
        url='https://www.makaan.com/listings?sortBy=date-desc&listingType=buy&pageType=LOCALITY_URLS&cityName=Hyderabad&localityName=ameerpet&suburbName=Hyderabad%20Central&cityId=12&localityId=51957&suburbId=10234&templateId=MAKAAN_LOCALITY_LISTING_BUY&page='+str(page)
        
        #url='https://www.makaan.com/hyderabad-property/miyapur-flats-for-sale-50393?page='+'str(page)'
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
# Returns the number of pages scrapped and time taken for scarpping those pages.
df = df.loc[~df.duplicated()]

# %%
df.to_csv('freshameerpermakkan.csv',index= False)
