# %%
from bs4 import BeautifulSoup as soup
from requests import get
import pandas as pd
import requests
import re

# %%
#Adyar has 6 pages data for post COVID

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,6):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/adyar-flats-for-sale-51248?beds=2,3&propertyType=apartment'
    else:
        url= 'https://www.makaan.com/chennai-property/adyar-flats-for-sale-51248?beds=2,3&propertyType=apartment&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_adyar = df.loc[~df.duplicated()]
print(df.shape)
df_adyar.to_csv('chennai_adyar.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/adyar-flats-for-sale-51248?beds=2,3&propertyType=apartment
# https://www.makaan.com/chennai-property/adyar-flats-for-sale-51248?beds=2,3&propertyType=apartment&page=3
# https://www.makaan.com/chennai-property/adyar-flats-for-sale-51248?beds=2,3&propertyType=apartment&page=4
# https://www.makaan.com/chennai-property/adyar-flats-for-sale-51248?beds=2,3&propertyType=apartment&page=5
# (80, 6)
# (80, 6)

# %%
#Anna nagar has 9 pages data for post COVID

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,10):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment'
    else:
        url= 'https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_annanagar = df.loc[~df.duplicated()]
print(df.shape)
df_annanagar.to_csv('chennai_annanagar.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=3
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=4
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=5
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=6
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=7
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=8
# https://www.makaan.com/chennai-property/anna-nagar-flats-for-sale-50379?beds=2,3&propertyType=apartment&page=9
# (148, 6)
# (148, 6)

# %%
#Chrompet has 9 pages data for post COVID

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,8):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment'
    else:
        url= 'https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_chrompet = df.loc[~df.duplicated()]
print(df.shape)
df_chrompet.to_csv('chennai_chrompet.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment
# https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment&page=3
# https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment&page=4
# https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment&page=5
# https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment&page=6
# https://www.makaan.com/chennai-property/chromepet-flats-for-sale-50286?beds=2,3&propertyType=apartment&page=7
# (101, 6)
# (101, 6)

# %% [markdown]
# #Karapakam has 9 pages data for post COVID

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,9):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment'
    else:
        url= 'https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_karapakam = df.loc[~df.duplicated()]
print(df.shape)
df_karapakam.to_csv('chennai_karapakam.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page=3
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page=4
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page=5
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page=6
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page=7
# https://www.makaan.com/chennai-property/karapakkam-flats-for-sale-52056?beds=2,3&propertyType=apartment&page=8
# (140, 6)
# (140, 6)

# %%
#T Nagar has 5 pages data for post COVID

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,6):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment'
    else:
        url= 'https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_TNagar = df.loc[~df.duplicated()]
print(df.shape)
df_TNagar.to_csv('chennai_Tnagar.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment
# https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment&page=3
# https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment&page=4
# https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment&page=5
# (78, 6)
# (78, 6)

# %%
#Only 1 page is available for KK Nagar

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,3):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/k-k-nagar-flats-for-sale-51274?beds=2,3,3plus&propertyType=apartment,villa,independent-house'
    else:
        url= 'https://www.makaan.com/chennai-property/t-nagar-flats-for-sale-51618?beds=2,3&propertyType=apartment&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_KKNagar = df.loc[~df.duplicated()]
print(df.shape)
df_KKNagar.to_csv('chennai_kknagar.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/k-k-nagar-flats-for-sale-51274?beds=2,3,3plus&propertyType=apartment,villa,independent-house
# (15, 6)
# (15, 6)

# %%
title = []
locationnew=[]
price=[]
price_per_sqft=[]
area_in_sqft=[]
building_status=[]
n_pages = 0
for page in range(2,7):  #The no. of pages you wanted to scrap considering pages available in the url.
    n_pages += 1
    #url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?budget=,'+'&page='+str(page)
    if((page == 1) | (page==2) ):
        url='https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house'
    else:
        url= 'https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house&page='+ str(page)

    print(url)
    # This for gets us into next page after every iteration.
    res = requests.get(url) # Here r is response data.
    
    page_html = soup(res.text, 'html.parser') 
    house_containers = page_html.find_all("li",class_="cardholder") # Class containing overall data of a property.
    for data in house_containers:
        type=data.find_all("a",class_="typelink") # Class containing title name of a property.
        for i in type:
            d=i.text
            title.append(d) 
        location=data.find_all("a",class_="loclink")
        #print(location)
        for i in location:
            
            loc = i.find("span",itemprop="addressLocality").text
            locationnew.append(loc)

        cost=data.find_all("td",class_="price")
        for i in cost:
            d=i.text
            if 'L' in d:
                a = d.split()[0]
                price.append(float(a)) # Type conversion of obtained data.
            elif 'Cr' in d:
                b = d.split()[0]
                price.append(float(b) * 100) # Coverting CRORES into LAKHS.
            else:  # If no value found in the class return value 0.
                e=0
                price.append(float(e)) 
                
        rate_sqft=data.find_all('td',class_="lbl rate")
        for i in rate_sqft:
            d=i.text
            res= d.split('/',)[0]
            r=re.sub(",","" ,res) # Substitute no character in the place of ,(comma).
            price_per_sqft.append(r)
            
        area_sqft=data.find_all('td',class_="size")
        for i in area_sqft:
            d=i.text
            area_in_sqft.append(d)
            
        building_status_=data.find_all("td",class_="val")
        for i in building_status_:
            d=i.text
            building_status.append(d)
df = pd.DataFrame()            
df['title']=title 
df['location']=locationnew
df['price(L)']=price
df['rate_persqft']=price_per_sqft
df['area_insqft']=area_in_sqft
df['building_status']=building_status

#print('You scraped {} pages containing {} properties.'.format(n_pages, len(title)))
print(df.shape)
# Returns the number of pages scrapped and time taken for scarpping those pages.
df_Velacheri = df.loc[~df.duplicated()]
print(df.shape)
df_Velacheri.to_csv('chennai_Velacheri.csv',index= False)
# Out:
# https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house
# https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house&page=3
# https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house&page=4
# https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house&page=5
# https://www.makaan.com/chennai-property/velachery-flats-for-sale-50306?beds=2,3,3plus&propertyType=apartment,villa,independent-house&page=6
# (100, 6)
# (100, 6)
