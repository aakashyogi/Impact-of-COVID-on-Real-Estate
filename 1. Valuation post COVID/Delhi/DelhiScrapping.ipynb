# %%
import requests 
import pandas as pd
import time
import random
from bs4 import BeautifulSoup

# %%
Output = pd.DataFrame()

# %%
Localities = ['Rohini','Lajpat-Nagar','Dwarka','Lajpat-Nagar-3','Lajpat-Nagar-2','Budh-Vihar','Shahbad-Dairy','Begham-Vihar','New-Friends-Colony','Kailash-Colony','Shahdara','Yamuna-Vihar','Laxmi-Nagar','Uttam-Nagar','Patel-Nagar','Vasant-Kunj','Govind-Puri','Gandhi-Nagar','Saket','Safdarjung-Enclave','Paschim-Vihar','Aashirwaad-Chowk','Akshardham-Temple','Alaknanda','Ali Vihar','Sultanpur','Chattarpur','Mehrauli','Mahavir-Enclave','Narela','Malviya-Nagar','Dilshad-Garden','Vasundhara-Enclave','Okhla','Karol-Bagh','New-Moti-Nagar','Sheikh-Sarai','Punjabi-Bagh','Alaknanda','Kalkaji','Hauz-Khas','Chittaranjan-Park']
for loc in Localities:
    Data = {}
    s = random.randrange(2,10)
    time.sleep(s)
    URL = 'https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&Locality='+loc+'&cityName=New-Delhi'
    r = requests.get(URL)
    soup = BeautifulSoup(r.content, 'html.parser') 
    small = soup.findAll(class_='flex relative clearfix m-srp-card__container')
    for part in small:
        got = part.get_text().split()
        #print(got)
        for i in range(len(got)):
            ############# Price ###########
            if got[i]=='Cr':
                Data['Price']=float(got[i-1])*10000000
            elif got[i]=='Lac':
                Data['Price']=float(got[i-1])*100000
        ############ Area per Sqft/yard ############
            if got[i]=='per':
                if got[i+1]=='sqft':
                    Data['Per_Sqft']=float(got[i-1])
                elif got[i+1]=='sqyrd':
                    Data['Per_Sqft']=float(got[i-1])*9
                elif got[i+1]=='sqm':
                    Data['Per_Sqft']=float(got[i-1])*10.7639
        ############ BHK apartment #####################
            if got[i]=='BHK':
                Data['BHK']=int(got[i-1])
        ########### Type of House:- Builder/Apartment ####
            if got[i]=='Apartment':
                Data['Type']='Apartment'
            elif got[i]=='Builder':
                Data['Type']='Builder_Floor'
        ############ Area ##############################
            if got[i]=='super' or got[i]=='carpet':
                if got[i+3]=='sqft':
                    Data['Area']=int(got[i+2])
                elif got[i+3]=='sqyrd':
                    Data['Area']=int(got[i+2])*9
                elif got[i+3]=='sqm':
                    Data['Area']=int(got[i+2])*10.7639
    ############# Status #########################
            if got[i]=='status':
                if got[i+1]=='Ready':
                    Data['Status']='Ready_to_move'
                elif got[i+1]=='Possession':
                    Data['Status']='Almost_ready'
    ############# Transaction #########################
            if got[i]=='transaction':
                if got[i+1]=='New':
                    Data['Transaction']='New_Property'
                elif got[i+1]=='Resale':
                    Data['Transaction']='Resale'
    ############# Furnishing #########################
            if got[i]=='furnishing':
                if got[i+1]=='Unfurnished':
                    Data['Furnishing']='Unfurnished'
                elif got[i+1]=='Furnished':
                    Data['Furnishing']='Furnished' 
                elif got[i+1]=='Semi-Furnished':
                    Data['Furnishing']='Semi-Furnished' 
    ############# Parking #########################
            if got[i]=='parking':
                Data['Parking']=int(got[i+1])
    ############# Locality #########################
            if got[i]=='in':
                j=i+1
                string =got[j]
                j+=1
                while(j<len(got)):
                    if got[j]=="What's":
                        break
                    else :
                        string +=(' '+got[j])
                    j+=1
                Data['Locality']=string
        
        
    ############# Bathroom #########################
            if got[i]=='bathroom':
                Data['Bathroom']=int(got[i+1])
                break
        
        Output = Output.append(Data,ignore_index=True)
    
    print(r.status_code)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
Output
# Out:
#            Area  BHK  Bathroom      Furnishing  \
# 0      600.0000  3.0       2.0  Semi-Furnished
# 1     1600.0000  3.0       3.0  Semi-Furnished
# 2      900.0000  3.0       2.0  Semi-Furnished
# 3     1050.0000  2.0       2.0     Unfurnished
# 4      350.0000  1.0       1.0  Semi-Furnished
# 5     1000.0000  4.0       3.0  Semi-Furnished
# 6     1300.0000  4.0       3.0  Semi-Furnished
# 7      600.0000  2.0       2.0  Semi-Furnished
# 8      900.0000  3.0       2.0  Semi-Furnished
# 9     1200.0000  3.0       2.0     Unfurnished
# 10    1350.0000  4.0       3.0  Semi-Furnished
# 11     400.0000  1.0       1.0       Furnished
# 12    1350.0000  3.0       2.0       Furnished
# 13     550.0000  2.0       2.0  Semi-Furnished
# 14     680.0000  3.0       2.0  Semi-Furnished
# 15     470.0000  2.0       2.0  Semi-Furnished
# 16    1100.0000  3.0       3.0       Furnished
# 17     900.0000  3.0       2.0  Semi-Furnished
# 18     645.8340  3.0       2.0  Semi-Furnished
# 19     861.1120  2.0       1.0  Semi-Furnished
# 20    1110.0000  2.0       1.0     Unfurnished
# 21    1090.0000  2.0       2.0       Furnished
# 22    1050.0000  3.0       2.0  Semi-Furnished
# 23     861.1120  2.0       1.0     Unfurnished
# 24     320.0000  1.0       1.0  Semi-Furnished
# 25    2000.0000  3.0       3.0       Furnished
# 26     764.0000  2.0       2.0       Furnished
# 27     279.8614  1.0       1.0  Semi-Furnished
# 28     800.0000  2.0       2.0  Semi-Furnished
# 29     790.0000  2.0       2.0     Unfurnished
# ...         ...  ...       ...             ...
# 1280  2475.0000  4.0       4.0     Unfurnished
# 1281  4118.0000  4.0       5.0     Unfurnished
# 1282  1000.0000  3.0       3.0  Semi-Furnished
# 1283  1900.0000  3.0       3.0     Unfurnished
# 1284  1700.0000  3.0       3.0     Unfurnished
# 1285  2700.0000  4.0       4.0  Semi-Furnished
# 1286  1500.0000  3.0       3.0     Unfurnished
# 1287  1100.0000  3.0       3.0  Semi-Furnished
# 1288  1300.0000  4.0       4.0  Semi-Furnished
# 28                                     Rohini Sector 18      1.0  10500000.0
# 29                Printers Apartments, Rohini Sector 13      2.0  11500000.0
# ...                                                 ...      ...         ...
# 1280                                  Chittaranjan Park      NaN  52500000.0
# 1281                                  Chittaranjan Park      3.0  55000000.0
# 1282                          Chittaranjan Park Block E      1.0  23000000.0
# 1283          Arya Chittaranjan Park, Chittaranjan Park      1.0  32500000.0
# 1284                          Chittaranjan Park Block C      1.0  39000000.0
# 1285                                  Chittaranjan Park      1.0  42500000.0
# 1286                          Chittaranjan Park Block G      1.0  26000000.0
# 1287                          Chittaranjan Park Block D      2.0  21000000.0
# 1288                                  Chittaranjan Park      2.0  18500000.0
# 1289             Omdev Homes, Chittaranjan Park Block D      1.0  21000000.0
# 1290                                  Chittaranjan Park      1.0   5500000.0
# 1291                                  Chittaranjan Park      2.0  18000000.0
# 1292                                  Chittaranjan Park      1.0   7500000.0
# 1293                                  Chittaranjan Park      2.0  29000000.0
# 1294  Chittaranjan Park carpet area 1000 sqft status...      2.0  11000000.0
# 1295                                  Chittaranjan Park      2.0  21000000.0
# 1296                                  Chittaranjan Park      1.0  28000000.0
# 1297                                  Chittaranjan Park      1.0  17500000.0
# 1298                             Nehru Enclave, Kalkaji      1.0  25000000.0
# 1299                          Chittaranjan Park Block G      1.0  27500000.0
# 1300  Chittaranjan Park carpet area 250 sqyrd status...      1.0  27000000.0
# 1301      Prime Luxury Builder Floor, Chittaranjan Park      3.0  60000000.0
# 1302  Arya Chittaranjan Park, Chittaranjan Park Block B      1.0  20500000.0
# 1303                                  Chittaranjan Park      3.0  69500000.0
# 1304                                  Chittaranjan Park      3.0  23000000.0
# 1305          Arya Chittaranjan Park, Chittaranjan Park      3.0  15500000.0
# 1306                                  Chittaranjan Park      2.0  23000000.0
# 1307                                  Chittaranjan Park      2.0  14500000.0
# 1308  Chittaranjan Park carpet area 900 sqft status ...      1.0  15000000.0
# 1309  Chittaranjan Park carpet area 160 sqyrd status...      1.0  13000000.0
#
#              Status   Transaction           Type  Per_Sqft
# 0     Ready_to_move  New_Property  Builder_Floor       NaN
# 1      Almost_ready  New_Property  Builder_Floor       NaN
# 2     Ready_to_move  New_Property  Builder_Floor       NaN
# 3     Ready_to_move        Resale      Apartment       NaN
# 4     Ready_to_move        Resale  Builder_Floor       NaN
# 5     Ready_to_move        Resale  Builder_Floor       NaN
# 6     Ready_to_move  New_Property  Builder_Floor       NaN
# 7     Ready_to_move  New_Property  Builder_Floor       NaN
# 8     Ready_to_move  New_Property  Builder_Floor       NaN
# 9     Ready_to_move        Resale      Apartment   13750.0
# 10    Ready_to_move  New_Property  Builder_Floor   13750.0
# 11    Ready_to_move  New_Property  Builder_Floor   13750.0
# 12    Ready_to_move        Resale      Apartment   13750.0
# 13    Ready_to_move        Resale  Builder_Floor   13750.0
# 14    Ready_to_move        Resale  Builder_Floor   13750.0
# 15    Ready_to_move  New_Property  Builder_Floor   13750.0
# 16    Ready_to_move        Resale      Apartment   13750.0
# 17    Ready_to_move  New_Property  Builder_Floor   13750.0
# 18    Ready_to_move        Resale  Builder_Floor   13750.0
# 19    Ready_to_move        Resale      Apartment    6968.0
# 20    Ready_to_move        Resale      Apartment    6968.0
# 21    Ready_to_move        Resale      Apartment    6968.0
# 22    Ready_to_move        Resale      Apartment    6968.0
# 23    Ready_to_move  New_Property      Apartment    6968.0
# 24    Ready_to_move        Resale  Builder_Floor    6968.0
# 25    Ready_to_move        Resale  Builder_Floor   11250.0
# 26    Ready_to_move        Resale  Builder_Floor   11250.0
# 27    Ready_to_move        Resale  Builder_Floor   11250.0
# 28    Ready_to_move        Resale      Apartment   11250.0
# 29    Ready_to_move        Resale      Apartment   11250.0
# ...             ...           ...            ...       ...
# 1280  Ready_to_move  New_Property  Builder_Floor       NaN
# 1281  Ready_to_move  New_Property  Builder_Floor       NaN
# 1282  Ready_to_move  New_Property  Builder_Floor       NaN
# 1283  Ready_to_move  New_Property  Builder_Floor       NaN
# 1284  Ready_to_move  New_Property  Builder_Floor       NaN
# 1285  Ready_to_move  New_Property  Builder_Floor   15741.0
# 1286  Ready_to_move        Resale  Builder_Floor   15741.0
# 1287  Ready_to_move        Resale  Builder_Floor   15741.0
# 1288  Ready_to_move  New_Property  Builder_Floor   15741.0
# 1289  Ready_to_move  New_Property  Builder_Floor   15741.0
# 1290  Ready_to_move        Resale      Apartment    4889.0
# 1291  Ready_to_move  New_Property  Builder_Floor    4889.0
# 1292  Ready_to_move        Resale      Apartment    4889.0
# 1293  Ready_to_move        Resale      Apartment    4889.0
# 1294  Ready_to_move        Resale  Builder_Floor    4889.0
# 1295  Ready_to_move  New_Property  Builder_Floor    4889.0
# 1296  Ready_to_move        Resale  Builder_Floor   13333.0
# 1297  Ready_to_move  New_Property  Builder_Floor   13333.0
# 1298  Ready_to_move        Resale  Builder_Floor   13333.0
# 1299  Ready_to_move        Resale  Builder_Floor   13333.0
# 1300  Ready_to_move  New_Property  Builder_Floor   13333.0
# 1301  Ready_to_move  New_Property  Builder_Floor   13333.0
# 1302  Ready_to_move        Resale  Builder_Floor  128125.0
# 1303  Ready_to_move  New_Property  Builder_Floor  128125.0
# 1304  Ready_to_move  New_Property  Builder_Floor  128125.0
# 1305  Ready_to_move  New_Property  Builder_Floor  128125.0
# 1306  Ready_to_move  New_Property  Builder_Floor   17037.0
# 1307  Ready_to_move        Resale  Builder_Floor   17037.0
# 1308  Ready_to_move        Resale  Builder_Floor   17037.0
# 1309  Ready_to_move  New_Property  Builder_Floor   17037.0
#
# [1310 rows x 11 columns]

# %%
Output.to_csv('MagicBricks.csv')
